# %%
print("hello world")
# Out:
# hello world

# %%
# 숫자형은 어떻게 만들고 사용할까?
## 정수형
a=123
b=-123
c=0

# %%
print(a)
print(b)
print(c)
# Out:
# 123
# -123
# 0

# %%
## 실수형
a=3.14
b=-3.14
print(a)
print(b)
# Out:
# 3.14
# -3.14

# %%
## 8진수와 16진수
a=0o177
print(a)

1*8^2 + 7*8^1 + 7*8^0 = 64 + 56 + 7 = 127
# Out:
#   Cell In[17], line 5
#     1*8^2 + 7*8^1 + 7*8^0 = 64 + 56 + 7 = 127
#     ^
# SyntaxError: cannot assign to expression

# %%
a=0x8ff
print(a)
print(16**2*8+15*16**1+15)
# Out:
# 2303
# 2303

# %%
b=0xabc
print(b)
print(16**2*10+16**1*11+12)
# Out:
# 2748
# 2748

# %%
## 사칙연산
a=3
b=4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 7
# -1
# 12
# 0.75

# %%
a=3
b=4

print(a**b)
print(81**0.5)
# Out:
# 81
# 9.0

# %%
## 나눗셈 후 나머지를 변환하는 %연산자
print(7%3)
7/3
# Out:
# 1
# 2.3333333333333335

# %%
## 나눗셈 후 몫을 변환하는 //연산자
print(7//4)
7/4
# Out:
# 1
# 1.75

# %%
## 복합연산자

a=1

#a=a+1
a+=1
print(a)
# Out:
# 2
